# %% [markdown]
# Meteorites in France from 1492 to 2014
#
# Data taken from www.lpi.usra.edu on March 25 2022

# %%
import pandas as pd
import seaborn as sns
import geopandas as gpd
import contextily as cx
import numpy as np
import matplotlib.pyplot as plt

# %%
#The data for France comes from the following link
original_path = "https://www.lpi.usra.edu/meteor/metbull.php?sea=%2A&sfor=names&ants=&nwas=&falls=&valids=&stype=contains&lrec=50&map=ge&browse=&country=France&srt=name&categ=All&mblist=All&rect=&phot=&strewn=&snew=0&pnt=Normal%20table&dr=&page=1"

# %%
# I created an html file with just the needed data (for speed)
file4 = "meteori-1-2.html"

# %%
table = pd.read_html(file4)

# %%
table = table[0]

# %%
table.head()
# Out:
#                     0         1  2     3                             4  \
# 0             Agen **  Official  Y  1814             Aquitaine, France
# 1  Aire-sur-la-Lys **  Official  Y  1769    Nord-Pas-de-Calais, France
# 2            Alais **  Official  Y  1806  Languedoc-Roussillon, France
# 3  Alby sur Chéran **  Official  Y  2002           Rhone-Alpes, France
# 4           Angers **  Official  Y  1822      Pays de la Loire, France
#
#                5       6     7                       8    9
# 0             H5   30 kg   NaN   (44.427176, 0.498226)  NaN
# 1        Unknown  6.8 kg   NaN   (50.609061, 2.486308)  NaN
# 2            CI1    6 kg   NaN   (44.057056, 4.184386)  NaN
# 3  Eucrite-mmict   252 g  88.0   (45.818611, 6.001111)  NaN
# 4             L6  1007 g   NaN  (47.466670, -0.550000)  NaN

# %%
table.duplicated().sum()
# Out:
# 40

# %%
table[8].value_counts(dropna=False)
# Out:
# (46.633330, 0.166670)       2
# (43.500000, 6.000000)       2
# (43.883330, 1.383330)       2
# (49.033330, -1.433330)      2
# (-21.733330, 165.900000)    2
#                            ..
# (47.500000, 7.316670)       1
# (44.383330, 2.816670)       1
# (46.250000, -1.100000)      1
# (48.154597, 6.588658)       1
# (47.700000, 1.066670)       1
# Name: 8, Length: 89, dtype: int64

# %%
table = table.drop_duplicates()
print(len(table))
# Out:
# 89

# %%
table.rename(columns={0: 'Name', 1: 'Status', 2: 'Fall', 3: 'Year', 4: 'Place', 
                5: 'Type', 6: 'Mass_str', 7: 'MetBull', 8: '(Lat,Long)', 9: 'Notes' }, inplace=True)
print(table.head())
# Out:
#                  Name    Status Fall  Year                         Place  \
# 0             Agen **  Official    Y  1814             Aquitaine, France
# 1  Aire-sur-la-Lys **  Official    Y  1769    Nord-Pas-de-Calais, France
# 2            Alais **  Official    Y  1806  Languedoc-Roussillon, France
# 3  Alby sur Chéran **  Official    Y  2002           Rhone-Alpes, France
# 4           Angers **  Official    Y  1822      Pays de la Loire, France
#
#             Type Mass_str  MetBull              (Lat,Long) Notes
# 0             H5    30 kg      NaN   (44.427176, 0.498226)   NaN
# 1        Unknown   6.8 kg      NaN   (50.609061, 2.486308)   NaN
# 2            CI1     6 kg      NaN   (44.057056, 4.184386)   NaN
# 3  Eucrite-mmict    252 g     88.0   (45.818611, 6.001111)   NaN
# 4             L6   1007 g      NaN  (47.466670, -0.550000)   NaN

# %%
table["Units"] = table["Mass_str"].str.extract(r'( +\w+$)')
table["Units"].value_counts(dropna=False)
# Out:
#  kg    50
#  g     31
# NaN     8
# Name: Units, dtype: int64

# %%
table[table["Units"].isnull()]
# Out:
#                Name    Status Fall         Year  \
# 14       Carpentras  Doubtful    Y         1738
# 22       Cormeilles    Pseudo  NaN          NaN
# 31           Grazac    Pseudo    Y         1885
# 33     Hautes Alpes    Pseudo  NaN          NaN
# 46          Langeac    Pseudo    Y          NaN
# 51         Limousin  Doubtful    Y         1540
# 64          Nicorps  Official    Y         1750
# 70  Rochechouart **    Crater  NaN  201 Â± 2 Ma
#
#                                  Place                Type Mass_str  MetBull  \
# 14  Provence-Alpes-Cote d'Azur, France  Doubtful meteorite      NaN      NaN
# 22              Ile-del-France, France     Pseudometeorite      NaN      NaN
# 31                    Auvergne, France     Pseudometeorite      NaN      NaN
# 33                              France     Pseudometeorite      NaN      NaN
# 46                    Auvergne, France     Pseudometeorite      NaN      NaN
# 51                    Limousin, France  Doubtful meteorite      NaN      NaN
# 64             Basse-Normandie, France          Stone-uncl      NaN      NaN
# 70                    Limousin, France       Impact Crater      NaN      NaN
#
#                 (Lat,Long)      Notes Units
# 14   (44.050000, 5.050000)        NaN   NaN
# 22   (48.983330, 2.216670)        NaN   NaN
# 31   (45.183330, 4.283330)        NaN   NaN
# 33                     NaN        NaN   NaN
# 46   (45.100000, 3.516670)        NaN   NaN
# 51   (45.600000, 1.500000)        NaN   NaN
# 64  (49.033330, -1.433330)        NaN   NaN
# 70   (45.833330, 0.933330)  From EIDB   NaN

# %%
table["Status"].value_counts()
# Out:
# Official       76
# Doubtful        5
# Pseudo          5
# Discredited     2
# Crater          1
# Name: Status, dtype: int64

# %%
table = table.dropna(subset=["Units"])
table.head()
# Out:
#                  Name    Status Fall  Year                         Place  \
# 0             Agen **  Official    Y  1814             Aquitaine, France
# 1  Aire-sur-la-Lys **  Official    Y  1769    Nord-Pas-de-Calais, France
# 2            Alais **  Official    Y  1806  Languedoc-Roussillon, France
# 3  Alby sur Chéran **  Official    Y  2002           Rhone-Alpes, France
# 4           Angers **  Official    Y  1822      Pays de la Loire, France
#
#             Type Mass_str  MetBull              (Lat,Long) Notes Units
# 0             H5    30 kg      NaN   (44.427176, 0.498226)   NaN    kg
# 1        Unknown   6.8 kg      NaN   (50.609061, 2.486308)   NaN    kg
# 2            CI1     6 kg      NaN   (44.057056, 4.184386)   NaN    kg
# 3  Eucrite-mmict    252 g     88.0   (45.818611, 6.001111)   NaN     g
# 4             L6   1007 g      NaN  (47.466670, -0.550000)   NaN     g

# %%
table["Mass"] = table["Mass_str"].str.extract(r'(^\d+)')
table.head()
# Out:
#                  Name    Status Fall  Year                         Place  \
# 0             Agen **  Official    Y  1814             Aquitaine, France
# 1  Aire-sur-la-Lys **  Official    Y  1769    Nord-Pas-de-Calais, France
# 2            Alais **  Official    Y  1806  Languedoc-Roussillon, France
# 3  Alby sur Chéran **  Official    Y  2002           Rhone-Alpes, France
# 4           Angers **  Official    Y  1822      Pays de la Loire, France
#
#             Type Mass_str  MetBull              (Lat,Long) Notes Units  Mass
# 0             H5    30 kg      NaN   (44.427176, 0.498226)   NaN    kg    30
# 1        Unknown   6.8 kg      NaN   (50.609061, 2.486308)   NaN    kg     6
# 2            CI1     6 kg      NaN   (44.057056, 4.184386)   NaN    kg     6
# 3  Eucrite-mmict    252 g     88.0   (45.818611, 6.001111)   NaN     g   252
# 4             L6   1007 g      NaN  (47.466670, -0.550000)   NaN     g  1007

# %%
x = table[table["Units"] == ' g']
x.head()
# Out:
#                   Name    Status Fall  Year                     Place  \
# 3   Alby sur Chéran **  Official    Y  2002       Rhone-Alpes, France
# 4            Angers **  Official    Y  1822  Pays de la Loire, France
# 6              Asco **  Official    Y  1805             Corse, France
# 7            Aubres **  Official    Y  1836       Rhone-Alpes, France
# 10      Bacqueville **  Official  NaN  1999   Haute-Normandie, France
#
#              Type Mass_str  MetBull              (Lat,Long) Notes Units  Mass
# 3   Eucrite-mmict    252 g     88.0   (45.818611, 6.001111)   NaN     g   252
# 4              L6   1007 g      NaN  (47.466670, -0.550000)   NaN     g  1007
# 6              H6     41 g      NaN   (42.450000, 9.033330)   NaN     g    41
# 7         Aubrite    800 g      NaN   (44.383330, 5.166670)   NaN     g   800
# 10             H6    395 g     87.0   (49.326472, 1.355106)   NaN     g   395

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 0 to 88
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        81 non-null     object
#  1   Status      81 non-null     object
#  2   Fall        66 non-null     object
#  3   Year        81 non-null     object
#  4   Place       81 non-null     object
#  5   Type        81 non-null     object
#  6   Mass_str    81 non-null     object
#  7   MetBull     19 non-null     float64
#  8   (Lat,Long)  81 non-null     object
#  9   Notes       1 non-null      object
#  10  Units       81 non-null     object
#  11  Mass        81 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 8.2+ KB

# %%
table['Mass'] = table['Mass'].astype(float)
table['Mass'].describe()
# Out:
# count      81.000000
# mean      244.740741
# std       418.257868
# min         2.000000
# 25%         6.000000
# 50%        37.000000
# 75%       277.000000
# max      1820.000000
# Name: Mass, dtype: float64

# %%
table['Mass_kg'] = table['Mass'].where(table['Units'] == ' kg', table['Mass']/1000)
table['Mass_kg'].describe()
# Out:
# count     81.000000
# mean      33.409074
# std       99.578079
# min        0.019000
# 25%        0.780000
# 50%        4.000000
# 75%       14.000000
# max      626.000000
# Name: Mass_kg, dtype: float64

# %%
table[table['Mass'] > 1].sort_values(by='Mass_kg')
# Out:
#                 Name    Status Fall  Year                               Place  \
# 34         Henvic **  Official  NaN  1991                    Bretagne, France
# 6            Asco **  Official    Y  1805                       Corse, France
# 21   Contis-Plage **  Official  NaN  2000                   Aquitaine, France
# 20        Clohars **  Official    Y  1822                              France
# 32           Groslée    Pseudo  NaN  1827                 Rhone-Alpes, France
# ..               ...       ...  ...   ...                                 ...
# 59      Montferré **  Official    Y  1923        Languedoc-Roussillon, France
# 85  Saint-Séverin **  Official    Y  1966            Poitou-Charentes, France
# 58      Mont Dieu **  Official  NaN  1994           Champagne-Ardenne, France
# 71    Saint-Aubin **  Official  NaN  1968           Champagne-Ardenne, France
# 41         La Caille  Official  NaN  1828  Provence-Alpes-Cote d'Azur, France
#
#                Type Mass_str  MetBull              (Lat,Long)  \
# 34               L5     19 g     73.0  (48.650000, -3.916670)
# 6                H6     41 g      NaN   (42.450000, 9.033330)
# 21               H5     44 g    101.0  (44.083330, -1.316670)
# 20               L4   48.6 g      NaN  (47.890000, -4.060000)
# 32  Pseudometeorite     52 g      NaN   (45.700000, 5.616670)
# ..              ...      ...      ...                     ...
# 59               H5   149 kg     51.0   (43.390560, 1.962500)
# 85              LL6   271 kg     40.0   (45.300000, 0.233330)
# 58  Iron, ungrouped   360 kg     81.0   (49.550000, 4.866670)
# 71      Iron, IIIAB   472 kg     87.0   (48.483330, 3.583330)
# 41  Iron, ungrouped   626 kg      NaN   (43.733330, 6.783330)
#
#                       Notes Units   Mass  Mass_kg
# 34                      NaN     g   19.0    0.019
# 6                       NaN     g   41.0    0.041
# 21                      NaN     g   44.0    0.044
# 20  Coordinates approximate     g   48.0    0.048
# 32                      NaN     g   52.0    0.052
# ..                      ...   ...    ...      ...
# 59                      NaN    kg  149.0  149.000
# 85                      NaN    kg  271.0  271.000
# 58                      NaN    kg  360.0  360.000
# 71                      NaN    kg  472.0  472.000
# 41                      NaN    kg  626.0  626.000
#
# [81 rows x 13 columns]

# %%
table['Year'] = table['Year'].astype('int32')
table['Year'].describe()
# Out:
# count      81.000000
# mean     1865.716049
# std        88.891962
# min      1492.000000
# 25%      1822.000000
# 50%      1856.000000
# 75%      1923.000000
# max      2014.000000
# Name: Year, dtype: float64

# %%
bins = [1400, 1800, 1900, 2000, 2100 ]
years = pd.cut(table['Year'], bins)
pd.value_counts(years)
# Out:
# (1800, 1900]    49
# (1900, 2000]    18
# (1400, 1800]     9
# (2000, 2100]     5
# Name: Year, dtype: int64

# %%
_ = table['Mass_kg'].hist(bins= 12, figsize=(10, 7))

# %%
columns = ["Mass_kg"]
sns.set_theme(style="darkgrid")


sns.displot(
    table, x ="Mass_kg", col=years, height=5, aspect=.8)

# %%
table['Lat'] = table['(Lat,Long)'].str.extract(r'\((.*),').astype(float)
table['Long'] = table['(Lat,Long)'].str.extract(r',(.*)\)').astype(float)
table
# Out:
#                   Name       Status Fall  Year                         Place  \
# 0              Agen **     Official    Y  1814             Aquitaine, France
# 1   Aire-sur-la-Lys **     Official    Y  1769    Nord-Pas-de-Calais, France
# 2             Alais **     Official    Y  1806  Languedoc-Roussillon, France
# 3   Alby sur Chéran **     Official    Y  2002           Rhone-Alpes, France
# 4            Angers **     Official    Y  1822      Pays de la Loire, France
# ..                 ...          ...  ...   ...                           ...
# 84          Sologne **  Discredited    Y  1860                Centre, France
# 85    Saint-Séverin **     Official    Y  1966      Poitou-Charentes, France
# 86            Toulouse     Official    Y  1812         Midi-Pyrenees, France
# 87           Villedieu     Official  NaN  1890             Bourgogne, France
# 88             Vouillé     Official    Y  1831      Poitou-Charentes, France
#
#              Type Mass_str  MetBull              (Lat,Long) Notes Units  \
# 0              H5    30 kg      NaN   (44.427176, 0.498226)   NaN    kg
# 1         Unknown   6.8 kg      NaN   (50.609061, 2.486308)   NaN    kg
# 2             CI1     6 kg      NaN   (44.057056, 4.184386)   NaN    kg
# 3   Eucrite-mmict    252 g     88.0   (45.818611, 6.001111)   NaN     g
# 4              L6   1007 g      NaN  (47.466670, -0.550000)   NaN     g
# ..            ...      ...      ...                     ...   ...   ...
# 84             H5     54 g     85.0   (47.366670, 1.733330)   NaN     g
# 85            LL6   271 kg     40.0   (45.300000, 0.233330)   NaN    kg
# 86             H6   1030 g      NaN   (43.823815, 1.156998)   NaN     g
# 87             H4    14 kg      NaN   (47.916670, 4.350000)   NaN    kg
# 88             L6    20 kg      NaN   (46.633330, 0.166670)   NaN    kg
#
#       Mass  Mass_kg        Lat      Long
# 0     30.0   30.000  44.427176  0.498226
# 1      6.0    6.000  50.609061  2.486308
# 2      6.0    6.000  44.057056  4.184386
# 3    252.0    0.252  45.818611  6.001111
# 4   1007.0    1.007  47.466670 -0.550000
# ..     ...      ...        ...       ...
# 84    54.0    0.054  47.366670  1.733330
# 85   271.0  271.000  45.300000  0.233330
# 86  1030.0    1.030  43.823815  1.156998
# 87    14.0   14.000  47.916670  4.350000
# 88    20.0   20.000  46.633330  0.166670
#
# [81 rows x 15 columns]

# %%
table = gpd.GeoDataFrame(table, geometry=gpd.points_from_xy(table['Long'], table['Lat']), crs = 'WGS 84')
table = table.drop(columns=['MetBull','Notes','Mass', 'Mass_str', 'Units'])

# %%
table.head()
# Out:
#                  Name    Status Fall  Year                         Place  \
# 0             Agen **  Official    Y  1814             Aquitaine, France
# 1  Aire-sur-la-Lys **  Official    Y  1769    Nord-Pas-de-Calais, France
# 2            Alais **  Official    Y  1806  Languedoc-Roussillon, France
# 3  Alby sur Chéran **  Official    Y  2002           Rhone-Alpes, France
# 4           Angers **  Official    Y  1822      Pays de la Loire, France
#
#             Type              (Lat,Long)  Mass_kg        Lat      Long  \
# 0             H5   (44.427176, 0.498226)   30.000  44.427176  0.498226
# 1        Unknown   (50.609061, 2.486308)    6.000  50.609061  2.486308
# 2            CI1   (44.057056, 4.184386)    6.000  44.057056  4.184386
# 3  Eucrite-mmict   (45.818611, 6.001111)    0.252  45.818611  6.001111
# 4             L6  (47.466670, -0.550000)    1.007  47.466670 -0.550000
#
#                     geometry
# 0   POINT (0.49823 44.42718)
# 1   POINT (2.48631 50.60906)
# 2   POINT (4.18439 44.05706)
# 3   POINT (6.00111 45.81861)
# 4  POINT (-0.55000 47.46667)

# %%
table.plot()
# Out:
# <AxesSubplot:>

# %%
table.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
dep_df = gpd.read_file('contour-des-departements.geojson')
table_Fr = gpd.sjoin(table, dep_df, how='inner')
table_Fr = table_Fr.to_crs(epsg =2154)

fig, ax = plt.subplots(figsize=(20,10))

scatter = ax.scatter(table_Fr.bounds['minx'],table_Fr.bounds['miny'], s=table_Fr['Mass_kg'], 
                    color = 'red', alpha=.7)
ax.legend(*scatter.legend_elements("sizes", num=5, fmt="{x:.0f} kg", color = 'red'), labelspacing = 2)
ax.grid(False)
ax.set_axis_off()
ax.set_title("Meteorites in France from 1492 to 2014 ", fontdict={'fontsize': 18} )
cx.add_basemap(ax, crs = 'EPSG:2154')

labels = table_Fr.nlargest(4, columns=['Mass_kg'])
for i,j,k in zip(labels.bounds['minx'], labels.bounds['miny'], labels['Year']):
    ax.annotate(str(k), xy=(i,j), color='black',
                fontsize="small",
                horizontalalignment='center',
                verticalalignment='center' )



plt.show()
